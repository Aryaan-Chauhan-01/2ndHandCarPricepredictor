# %% [markdown]
# # Read Dataset

# %%
import pandas as pd
from matplotlib import pyplot as plt
dataframe = pd.read_csv('/kaggle/input/craigslist-carstrucks-data/vehicles.csv')

# %% [markdown]
# # Exploratory Data Analytics

# %%
dataframe
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# 0                     prescott    https://prescott.craigslist.org   6000
# 1                 fayetteville       https://fayar.craigslist.org  11900
# 2                 florida keys        https://keys.craigslist.org  21000
# 3       worcester / central MA   https://worcester.craigslist.org   1500
# 4                   greensboro  https://greensboro.craigslist.org   4900
# ...                        ...                                ...    ...
# 426875                 wyoming     https://wyoming.craigslist.org  23590
# 426876                 wyoming     https://wyoming.craigslist.org  30590
# 426877                 wyoming     https://wyoming.craigslist.org  34990
# 426878                 wyoming     https://wyoming.craigslist.org  28990
# 426879                 wyoming     https://wyoming.craigslist.org  30590
#
#           year manufacturer                     model condition    cylinders  \
# 0          NaN          NaN                       NaN       NaN          NaN
# 1          NaN          NaN                       NaN       NaN          NaN
# 2          NaN          NaN                       NaN       NaN          NaN
# 3          NaN          NaN                       NaN       NaN          NaN
# 4          NaN          NaN                       NaN       NaN          NaN
# ...        ...          ...                       ...       ...          ...
# 426875  2019.0       nissan         maxima s sedan 4d      good  6 cylinders
# 426876  2020.0        volvo  s60 t5 momentum sedan 4d      good          NaN
# 426877  2020.0     cadillac          xt4 sport suv 4d      good          NaN
# 426878  2018.0        lexus           es 350 sedan 4d      good  6 cylinders
# 426879  2019.0          bmw  4 series 430i gran coupe      good          NaN
#
#         ... size       type paint_color  \
# 0       ...  NaN        NaN         NaN
# 1       ...  NaN        NaN         NaN
# 2       ...  NaN        NaN         NaN
# 3       ...  NaN        NaN         NaN
# 4       ...  NaN        NaN         NaN
# ...     ...  ...        ...         ...
# 426875  ...  NaN      sedan         NaN
# 426876  ...  NaN      sedan         red
# 426877  ...  NaN  hatchback       white
# 426878  ...  NaN      sedan      silver
# 426879  ...  NaN      coupe         NaN
#
#                                                 image_url  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 426875  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 426876  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 426877  https://images.craigslist.org/00L0L_farM7bxnxR...
# 426878  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 426879  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                               description county state  \
# 0                                                     NaN    NaN    az
# 1                                                     NaN    NaN    ar
# 2                                                     NaN    NaN    fl
# 3                                                     NaN    NaN    ma
# 4                                                     NaN    NaN    nc
# ...                                                   ...    ...   ...
# 426875  Carvana is the safer way to buy a car During t...    NaN    wy
# 426876  Carvana is the safer way to buy a car During t...    NaN    wy
# 426877  Carvana is the safer way to buy a car During t...    NaN    wy
# 426878  Carvana is the safer way to buy a car During t...    NaN    wy
# 426879  Carvana is the safer way to buy a car During t...    NaN    wy
#
#               lat       long              posting_date
# 0             NaN        NaN                       NaN
# 1             NaN        NaN                       NaN
# 2             NaN        NaN                       NaN
# 3             NaN        NaN                       NaN
# 4             NaN        NaN                       NaN
# ...           ...        ...                       ...
# 426875  33.786500 -84.445400  2021-04-04T03:21:31-0600
# 426876  33.786500 -84.445400  2021-04-04T03:21:29-0600
# 426877  33.779214 -84.411811  2021-04-04T03:21:17-0600
# 426878  33.786500 -84.445400  2021-04-04T03:21:11-0600
# 426879  33.779214 -84.411811  2021-04-04T03:21:07-0600
#
# [426880 rows x 26 columns]

# %%
dataframe.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# max        82.390818     173.885502

# %%
import seaborn as sns

sns.heatmap(dataframe.isnull())
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot as plt

def piefig(name,tname):
    plt.figure(figsize=(10,10))
    plt.pie(dataframe[name].value_counts())
    plt.title(tname+' Density Index')
    plt.legend(dataframe[name].unique())
    plt.show()

# %%
piefig('drive','Drive')

# %%
piefig('manufacturer','Mannufacturer')

# %%
piefig('transmission','Transmission')

# %%
piefig('type','Type')

# %%
piefig('title_status','Title Status')

# %%
piefig('fuel','Fuel')

# %%
piefig('cylinders','Cylinders')

# %%
piefig('condition','Condition')

# %%
X=['transmission','type','fuel','condition','title_status','cylinders','drive','manufacturer'
    ,'state','paint_color','size']
for x in X:
    print("Unique values in : ",x,dataframe[x].unique())
# Out:
# Unique values in :  transmission [nan 'other' 'automatic' 'manual']
# Unique values in :  type [nan 'pickup' 'truck' 'other' 'coupe' 'SUV' 'hatchback' 'mini-van' 'sedan'
#  'offroad' 'bus' 'van' 'convertible' 'wagon']
# Unique values in :  fuel [nan 'gas' 'other' 'diesel' 'hybrid' 'electric']
# Unique values in :  condition [nan 'good' 'excellent' 'fair' 'like new' 'new' 'salvage']
# Unique values in :  title_status [nan 'clean' 'rebuilt' 'lien' 'salvage' 'missing' 'parts only']
# Unique values in :  cylinders [nan '8 cylinders' '6 cylinders' '4 cylinders' '5 cylinders' 'other'
#  '3 cylinders' '10 cylinders' '12 cylinders']
# Unique values in :  drive [nan 'rwd' '4wd' 'fwd']
# Unique values in :  manufacturer [nan 'gmc' 'chevrolet' 'toyota' 'ford' 'jeep' 'nissan' 'ram' 'mazda'
#  'cadillac' 'honda' 'dodge' 'lexus' 'jaguar' 'buick' 'chrysler' 'volvo'
#  'audi' 'infiniti' 'lincoln' 'alfa-romeo' 'subaru' 'acura' 'hyundai'
#  'mercedes-benz' 'bmw' 'mitsubishi' 'volkswagen' 'porsche' 'kia' 'rover'
#  'ferrari' 'mini' 'pontiac' 'fiat' 'tesla' 'saturn' 'mercury'
#  'harley-davidson' 'datsun' 'aston-martin' 'land rover' 'morgan']
# Unique values in :  state ['az' 'ar' 'fl' 'ma' 'nc' 'ny' 'or' 'pa' 'tx' 'wa' 'wi' 'al' 'ak' 'ca'
#  'co' 'ct' 'dc' 'de' 'ga' 'hi' 'id' 'il' 'in' 'ia' 'ks' 'ky' 'la' 'me'
#  'md' 'mi' 'mn' 'ms' 'mo' 'mt' 'ne' 'nv' 'nj' 'nm' 'nh' 'nd' 'oh' 'ok'
#  'ri' 'sc' 'sd' 'tn' 'ut' 'vt' 'va' 'wv' 'wy']
# Unique values in :  paint_color [nan 'white' 'blue' 'red' 'black' 'silver' 'grey' 'brown' 'yellow'
#  'orange' 'green' 'custom' 'purple']
# Unique values in :  size [nan 'full-size' 'mid-size' 'compact' 'sub-compact']

# %% [markdown]
# # Data Preprocessing

# %%
X=['posting_date','description','image_url','VIN','url','region_url','id',
   'model','lat','long','region','county']
for x in X:
    dataframe=dataframe.drop(x, axis=1)

# %%
dataframe
# Out:
#         price    year manufacturer condition    cylinders    fuel  odometer  \
# 0        6000     NaN          NaN       NaN          NaN     NaN       NaN
# 1       11900     NaN          NaN       NaN          NaN     NaN       NaN
# 2       21000     NaN          NaN       NaN          NaN     NaN       NaN
# 3        1500     NaN          NaN       NaN          NaN     NaN       NaN
# 4        4900     NaN          NaN       NaN          NaN     NaN       NaN
# ...       ...     ...          ...       ...          ...     ...       ...
# 426875  23590  2019.0       nissan      good  6 cylinders     gas   32226.0
# 426876  30590  2020.0        volvo      good          NaN     gas   12029.0
# 426877  34990  2020.0     cadillac      good          NaN  diesel    4174.0
# 426878  28990  2018.0        lexus      good  6 cylinders     gas   30112.0
# 426879  30590  2019.0          bmw      good          NaN     gas   22716.0
#
#        title_status transmission drive size       type paint_color state
# 0               NaN          NaN   NaN  NaN        NaN         NaN    az
# 1               NaN          NaN   NaN  NaN        NaN         NaN    ar
# 2               NaN          NaN   NaN  NaN        NaN         NaN    fl
# 3               NaN          NaN   NaN  NaN        NaN         NaN    ma
# 4               NaN          NaN   NaN  NaN        NaN         NaN    nc
# ...             ...          ...   ...  ...        ...         ...   ...
# 426875        clean        other   fwd  NaN      sedan         NaN    wy
# 426876        clean        other   fwd  NaN      sedan         red    wy
# 426877        clean        other   NaN  NaN  hatchback       white    wy
# 426878        clean        other   fwd  NaN      sedan      silver    wy
# 426879        clean        other   rwd  NaN      coupe         NaN    wy
#
# [426880 rows x 14 columns]

# %%
dataframe['year'] = 2022-dataframe['year']

# %% [markdown]
# import seaborn as sns
#
# sns.heatmap(dataframe.isnull())

# %% [markdown]
# # Label Encoding
# ### Our dataset has 12 characteristic categorical variables and 4 numerical variables (not including the price column). To apply ML models, we need to convert these categorical variables into numerical variables and LabelEncoder software from sklearn library is used to solve this problem. The below figure depicts label encoding which is performed on the dataset.

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
X=['manufacturer','fuel','transmission','type','drive','condition',
   'cylinders','title_status'
  ,'state','paint_color','size']
   #,'state','paint_color','size']
for x in X:
    dataframe[x] = le.fit_transform(dataframe[x])

# %%
dataframe
# Out:
#         price  year  manufacturer  condition  cylinders  fuel  odometer  \
# 0        6000   NaN            42          6          8     5       NaN
# 1       11900   NaN            42          6          8     5       NaN
# 2       21000   NaN            42          6          8     5       NaN
# 3        1500   NaN            42          6          8     5       NaN
# 4        4900   NaN            42          6          8     5       NaN
# ...       ...   ...           ...        ...        ...   ...       ...
# 426875  23590   3.0            31          2          5     2   32226.0
# 426876  30590   2.0            41          2          8     2   12029.0
# 426877  34990   2.0             6          2          8     0    4174.0
# 426878  28990   4.0            23          2          5     2   30112.0
# 426879  30590   3.0             4          2          8     2   22716.0
#
#         title_status  transmission  drive  size  type  paint_color  state
# 0                  6             3      3     4    13           12      3
# 1                  6             3      3     4    13           12      2
# 2                  6             3      3     4    13           12      9
# 3                  6             3      3     4    13           12     19
# 4                  6             3      3     4    13           12     27
# ...              ...           ...    ...   ...   ...          ...    ...
# 426875             0             2      1     4     9           12     50
# 426876             0             2      1     4     9            8     50
# 426877             0             2      3     4     4           10     50
# 426878             0             2      1     4     9            9     50
# 426879             0             2      2     4     3           12     50
#
# [426880 rows x 14 columns]

# %% [markdown]
# # Imputation
# ### The Iterative Imputer method is used to impute missing values and different estimators are applied, and the MSE of each estimator is calculated using cross_val_score.

# %% [markdown]
# dataframe.corr()

# %% [markdown]
# sns.heatmap(dataframe.corr())

# %% [markdown]
# dataframe.describe()

# %% [markdown]
# dataframe.isnull().sum()

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
ds=['cylinders','price','manufacturer','condition','fuel','title_status','year','transmission','drive','type','odometer'
    ,'state','paint_color','size']

imputer = IterativeImputer(imputation_order='ascending',random_state=1)
imputer.fit(dataframe[ds])
dataframe[ds]=imputer.transform(dataframe[ds])

# %%
dataframe
# Out:
#           price      year  manufacturer  condition  cylinders  fuel  \
# 0        6000.0  5.521509          42.0        6.0        8.0   5.0
# 1       11900.0  5.522447          42.0        6.0        8.0   5.0
# 2       21000.0  5.516007          42.0        6.0        8.0   5.0
# 3        1500.0  5.506725          42.0        6.0        8.0   5.0
# 4        4900.0  5.499347          42.0        6.0        8.0   5.0
# ...         ...       ...           ...        ...        ...   ...
# 426875  23590.0  3.000000          31.0        2.0        5.0   2.0
# 426876  30590.0  2.000000          41.0        2.0        8.0   2.0
# 426877  34990.0  2.000000           6.0        2.0        8.0   0.0
# 426878  28990.0  4.000000          23.0        2.0        5.0   2.0
# 426879  30590.0  3.000000           4.0        2.0        8.0   2.0
#
#             odometer  title_status  transmission  drive  size  type  \
# 0       12686.408327           6.0           3.0    3.0   4.0  13.0
# 1       12693.478335           6.0           3.0    3.0   4.0  13.0
# 2       12652.423149           6.0           3.0    3.0   4.0  13.0
# 3       12588.333728           6.0           3.0    3.0   4.0  13.0
# 4       12540.242005           6.0           3.0    3.0   4.0  13.0
# ...              ...           ...           ...    ...   ...   ...
# 426875  32226.000000           0.0           2.0    1.0   4.0   9.0
# 426876  12029.000000           0.0           2.0    1.0   4.0   9.0
# 426877   4174.000000           0.0           2.0    3.0   4.0   4.0
# 426878  30112.000000           0.0           2.0    1.0   4.0   9.0
# 426879  22716.000000           0.0           2.0    2.0   4.0   3.0
#
#         paint_color  state
# 0              12.0    3.0
# 1              12.0    2.0
# 2              12.0    9.0
# 3              12.0   19.0
# 4              12.0   27.0
# ...             ...    ...
# 426875         12.0   50.0
# 426876          8.0   50.0
# 426877         10.0   50.0
# 426878          9.0   50.0
# 426879         12.0   50.0
#
# [426880 rows x 14 columns]

# %%
dataframe.isnull().sum()
# Out:
# price           0
# year            0
# manufacturer    0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# drive           0
# size            0
# type            0
# paint_color     0
# state           0
# dtype: int64

# %% [markdown]
# # Removing Outliers

# %%
dataframe.corr()
# Out:
#                  price      year  manufacturer  condition  cylinders  \
# price         1.000000  0.004927      0.002058   0.001140   0.002191
# year          0.004927  1.000000      0.024870  -0.090201  -0.045785
# manufacturer  0.002058  0.024870      1.000000  -0.000738  -0.067827
# condition     0.001140 -0.090201     -0.000738   1.000000   0.288958
# cylinders     0.002191 -0.045785     -0.067827   0.288958   1.000000
# fuel         -0.000919 -0.092956     -0.043505  -0.018731   0.077436
# odometer      0.010034  0.157929      0.011751  -0.007918  -0.022001
# title_status -0.001108 -0.010325      0.019957  -0.071350  -0.098403
# transmission -0.000778 -0.124710      0.015749  -0.140187   0.156886
# drive         0.000015  0.093072     -0.040772   0.112561   0.295158
# size         -0.000432 -0.143755      0.002718   0.262869   0.334635
# type          0.003680  0.078522      0.037495   0.158917   0.197588
# paint_color   0.001914  0.017640      0.018437   0.151914   0.159877
# state        -0.000723 -0.011679     -0.015752   0.038417   0.021633
#
#                   fuel  odometer  title_status  transmission     drive  \
# price        -0.000919  0.010034     -0.001108     -0.000778  0.000015
# year         -0.092956  0.157929     -0.010325     -0.124710  0.093072
# manufacturer -0.043505  0.011751      0.019957      0.015749 -0.040772
# condition    -0.018731 -0.007918     -0.071350     -0.140187  0.112561
# cylinders     0.077436 -0.022001     -0.098403      0.156886  0.295158
# fuel          1.000000 -0.067393      0.039450      0.252074  0.102607
# odometer     -0.067393  1.000000     -0.001763     -0.098581  0.000268
# title_status  0.039450 -0.001763      1.000000     -0.027260  0.024247
# transmission  0.252074 -0.098581     -0.027260      1.000000  0.152139
# drive         0.102607  0.000268      0.024247      0.152139  1.000000
# size          0.100695 -0.055301      0.023471      0.210011  0.206207
# type         -0.111603  0.043860     -0.004229     -0.078179  0.252559
# paint_color  -0.056120  0.017355      0.076427     -0.055108  0.186127
# state        -0.023387 -0.001185     -0.000952     -0.006084 -0.046989
#
#                   size      type  paint_color     state
# price        -0.000432  0.003680     0.001914 -0.000723
# year         -0.143755  0.078522     0.017640 -0.011679
# manufacturer  0.002718  0.037495     0.018437 -0.015752
# condition     0.262869  0.158917     0.151914  0.038417
# cylinders     0.334635  0.197588     0.159877  0.021633
# fuel          0.100695 -0.111603    -0.056120 -0.023387
# odometer     -0.055301  0.043860     0.017355 -0.001185
# title_status  0.023471 -0.004229     0.076427 -0.000952
# transmission  0.210011 -0.078179    -0.055108 -0.006084
# drive         0.206207  0.252559     0.186127 -0.046989
# size          1.000000  0.153265     0.204028  0.008115
# type          0.153265  1.000000     0.230467 -0.001303
# paint_color   0.204028  0.230467     1.000000 -0.008608
# state         0.008115 -0.001303    -0.008608  1.000000

# %%
plt.figure(figsize=(10,7))
plt.xlabel("Price")
plt.ylabel("No of Cars")
plt.hist(dataframe['price'], bins = [0,50000,100000,150000])
plt.show()

# %% [markdown]
# sns.heatmap(dataframe.corr())

# %%
na='price'
pIQR=dataframe[na].quantile(0.75)-dataframe[na].quantile(0.25)
pupper=dataframe[na].quantile(0.75)+1.5*pIQR
plower=dataframe[na].quantile(0.25)-1.5*pIQR

print(na)
print(dataframe[na].quantile(0.75))
print(dataframe[na].quantile(0.05))
print(pupper)
print(plower)


na='odometer'
oIQR=dataframe[na].quantile(0.75)-dataframe[na].quantile(0.25)
oupper=dataframe[na].quantile(0.75)+1.5*oIQR
olower=dataframe[na].quantile(0.25)-1.5*oIQR

print(na)
print(dataframe[na].quantile(0.75))
print(dataframe[na].quantile(0.05))
print(oupper)
print(olower)

na='year'
yIQR=dataframe[na].quantile(0.75)-dataframe[na].quantile(0.25)
yupper=dataframe[na].quantile(0.75)+1.5*yIQR
ylower=dataframe[na].quantile(0.25)-1.5*yIQR

print(na)
print(dataframe[na].quantile(0.75))
print(dataframe[na].quantile(0.05))
print(yupper)
print(ylower)
# Out:
# price
# 26485.75
# 0.0
# 57364.375
# -24978.625
# odometer
# 133000.0
# 6360.0
# 275668.0
# -104780.0
# year
# 14.0
# 2.0
# 27.5
# -8.5

# %% [markdown]
# k=['year','odometer','year','manufacturer','condition','cylinders','fuel','odometer','title_status','transmission','drive','size','type','paint_color','state']
# for na in k:
#     pIQR=dataframe[na].quantile(0.75)-dataframe[na].quantile(0.25)
#     pupper=dataframe[na].quantile(0.75)+1.5*pIQR
#     plower=dataframe[na].quantile(0.25)-1.5*pIQR
#     print(na)
#     print(dataframe[na].quantile(0.75))
#     print(dataframe[na].quantile(0.05))
#     print(pupper)
#     print(plower)
#     dataframe=dataframe[dataframe.price<pupper]
#     dataframe=dataframe[dataframe.price>plower]

# %%
dataframe=dataframe[dataframe.price<pupper]
dataframe=dataframe[dataframe.price>1000]


dataframe=dataframe[dataframe.odometer<oupper]

dataframe=dataframe[dataframe.odometer>olower]

dataframe=dataframe[dataframe.year<yupper]

dataframe=dataframe[dataframe.year>ylower]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
k=['price','odometer','year','manufacturer','condition','cylinders','fuel','odometer','title_status','transmission','drive','size','type','paint_color','state']
for i in k:
    model = scaler.fit(pd.DataFrame(dataframe[i]))
    dataframe[i] = model.transform(pd.DataFrame(dataframe[i]))

# %% [markdown]
# # Dataset Description

# %%
dataframe
# Out:
#            price      year  manufacturer  condition  cylinders      fuel  \
# 0      -1.012483 -0.744682      1.822500   1.206251   1.038889  3.796317
# 1      -0.541889 -0.744509      1.822500   1.206251   1.038889  3.796317
# 2       0.183942 -0.745693      1.822500   1.206251   1.038889  3.796317
# 3      -1.371410 -0.747398      1.822500   1.206251   1.038889  3.796317
# 4      -1.100220 -0.748753      1.822500   1.206251   1.038889  3.796317
# ...          ...       ...           ...        ...        ...       ...
# 426875  0.390525 -1.207894      0.924766  -0.435308  -0.511527 -0.084631
# 426876  0.948856 -1.391598      1.740888  -0.435308   1.038889 -0.084631
# 426877  1.299807 -1.391598     -1.115538  -0.435308   1.038889 -2.671929
# 426878  0.821237 -1.024189      0.271869  -0.435308  -0.511527 -0.084631
# 426879  0.948856 -1.207894     -1.278762  -0.435308   1.038889 -0.084631
#
#         odometer  title_status  transmission     drive      size      type  \
# 0      -1.321877      5.391516      3.333261  1.302000  0.591935  1.223520
# 1      -1.321760      5.391516      3.333261  1.302000  0.591935  1.223520
# 2      -1.322439      5.391516      3.333261  1.302000  0.591935  1.223520
# 3      -1.323498      5.391516      3.333261  1.302000  0.591935  1.223520
# 4      -1.324294      5.391516      3.333261  1.302000  0.591935  1.223520
# ...          ...           ...           ...       ...       ...       ...
# 426875 -0.998786     -0.222357      2.051204 -0.353966  0.591935  0.339430
# 426876 -1.332747     -0.222357      2.051204 -0.353966  0.591935  0.339430
# 426877 -1.462631     -0.222357      2.051204  1.302000  0.591935 -0.765682
# 426878 -1.033742     -0.222357      2.051204 -0.353966  0.591935  0.339430
# 426879 -1.156036     -0.222357      2.051204  0.474017  0.591935 -0.986705
#
#         paint_color     state
# 0          1.009507 -1.359975
# 1          1.009507 -1.426124
# 2          1.009507 -0.963085
# 3          1.009507 -0.301600
# 4          1.009507  0.227587
# ...             ...       ...
# 426875     1.009507  1.749001
# 426876     0.125287  1.749001
# 426877     0.567397  1.749001
# 426878     0.346342  1.749001
# 426879     1.009507  1.749001
#
# [353438 rows x 14 columns]

# %%
dataframe.describe()
# Out:
#               price          year  manufacturer     condition     cylinders  \
# count  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05
# mean   1.399221e-17 -4.865106e-17 -1.572113e-16  2.830607e-17  1.065498e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.411131e+00 -1.759006e+00 -1.605211e+00 -1.256087e+00 -3.095553e+00
# 25%   -8.533582e-01 -8.404852e-01 -7.890892e-01 -8.456974e-01 -5.115267e-01
# 50%   -2.155842e-01 -1.056683e-01 -2.994161e-01 -4.353077e-01  5.278626e-03
# 75%    7.095711e-01  6.291486e-01  9.247665e-01  1.206251e+00  1.038889e+00
# max    3.082560e+00  3.201008e+00  1.822500e+00  1.206251e+00  1.038889e+00
#
#                fuel      odometer  title_status  transmission         drive  \
# count  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05
# mean  -9.187411e-18 -4.511280e-17 -6.155767e-17 -9.135142e-17 -2.979375e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -2.671929e+00 -1.531649e+00 -2.223574e-01 -5.129090e-01 -1.181948e+00
# 25%   -8.463084e-02 -8.760458e-01 -2.223574e-01 -5.129090e-01 -1.181948e+00
# 50%   -8.463084e-02 -6.001883e-02 -2.223574e-01 -5.129090e-01 -3.539655e-01
# 75%   -8.463084e-02  7.124214e-01 -2.223574e-01 -5.129090e-01  1.302000e+00
# max    3.796317e+00  3.024037e+00  5.391516e+00  3.333261e+00  1.302000e+00
#
#                size          type   paint_color         state
# count  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05
# mean  -1.148728e-16 -2.384304e-17 -2.609466e-17 -5.789879e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -2.455686e+00 -1.649772e+00 -1.643152e+00 -1.558421e+00
# 25%   -9.318755e-01 -7.656824e-01 -9.799871e-01 -9.630848e-01
# 50%    5.919350e-01  3.394300e-01  3.463421e-01 -3.700658e-02
# 75%    5.919350e-01  7.814750e-01  1.009507e+00  8.890716e-01
# max    5.919350e-01  1.223520e+00  1.009507e+00  1.749001e+00

# %%
len(dataframe)
# Out:
# 353438

# %%
dataframe.corr()
# Out:
#                  price      year  manufacturer  condition  cylinders  \
# price         1.000000 -0.626968     -0.045685   0.094898   0.221953
# year         -0.626968  1.000000      0.039358  -0.082598  -0.106824
# manufacturer -0.045685  0.039358      1.000000  -0.002786  -0.068370
# condition     0.094898 -0.082598     -0.002786   1.000000   0.280059
# cylinders     0.221953 -0.106824     -0.068370   0.280059   1.000000
# fuel         -0.009819 -0.177780     -0.039215  -0.007302   0.101882
# odometer     -0.570819  0.650461      0.023685  -0.013483  -0.107705
# title_status -0.081920  0.002103      0.017322  -0.061894  -0.105233
# transmission  0.313001 -0.305399      0.001973  -0.148269   0.181264
# drive        -0.062515 -0.000299     -0.058721   0.126081   0.283948
# size          0.195766 -0.193725     -0.002439   0.260800   0.352708
# type         -0.041462  0.075539      0.033856   0.155363   0.179687
# paint_color  -0.011121  0.035972      0.012648   0.130757   0.161110
# state         0.012136 -0.006966     -0.013772   0.029445   0.024724
#
#                   fuel  odometer  title_status  transmission     drive  \
# price        -0.009819 -0.570819     -0.081920      0.313001 -0.062515
# year         -0.177780  0.650461      0.002103     -0.305399 -0.000299
# manufacturer -0.039215  0.023685      0.017322      0.001973 -0.058721
# condition    -0.007302 -0.013483     -0.061894     -0.148269  0.126081
# cylinders     0.101882 -0.107705     -0.105233      0.181264  0.283948
# fuel          1.000000 -0.217076      0.020031      0.274035  0.097164
# odometer     -0.217076  1.000000     -0.008247     -0.414248 -0.078328
# title_status  0.020031 -0.008247      1.000000     -0.051621  0.019163
# transmission  0.274035 -0.414248     -0.051621      1.000000  0.153941
# drive         0.097164 -0.078328      0.019163      0.153941  1.000000
# size          0.130826 -0.194439      0.014012      0.242066  0.218638
# type         -0.111064  0.090124     -0.004703     -0.093627  0.245193
# paint_color  -0.056727  0.047864      0.068030     -0.058307  0.189138
# state        -0.015816  0.010193     -0.001089     -0.000415 -0.040404
#
#                   size      type  paint_color     state
# price         0.195766 -0.041462    -0.011121  0.012136
# year         -0.193725  0.075539     0.035972 -0.006966
# manufacturer -0.002439  0.033856     0.012648 -0.013772
# condition     0.260800  0.155363     0.130757  0.029445
# cylinders     0.352708  0.179687     0.161110  0.024724
# fuel          0.130826 -0.111064    -0.056727 -0.015816
# odometer     -0.194439  0.090124     0.047864  0.010193
# title_status  0.014012 -0.004703     0.068030 -0.001089
# transmission  0.242066 -0.093627    -0.058307 -0.000415
# drive         0.218638  0.245193     0.189138 -0.040404
# size          1.000000  0.149252     0.191636 -0.004597
# type          0.149252  1.000000     0.227108  0.001316
# paint_color   0.191636  0.227108     1.000000 -0.009815
# state        -0.004597  0.001316    -0.009815  1.000000

# %%
sns.heatmap(dataframe.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
plt.xlabel("Price")
plt.ylabel("No of Cars")
plt.hist(dataframe['price'], bins = [0,10000,20000,30000,40000,50000,60000])
plt.show()

# %%
dataframe.describe()
# Out:
#               price          year  manufacturer     condition     cylinders  \
# count  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05
# mean   1.399221e-17 -4.865106e-17 -1.572113e-16  2.830607e-17  1.065498e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.411131e+00 -1.759006e+00 -1.605211e+00 -1.256087e+00 -3.095553e+00
# 25%   -8.533582e-01 -8.404852e-01 -7.890892e-01 -8.456974e-01 -5.115267e-01
# 50%   -2.155842e-01 -1.056683e-01 -2.994161e-01 -4.353077e-01  5.278626e-03
# 75%    7.095711e-01  6.291486e-01  9.247665e-01  1.206251e+00  1.038889e+00
# max    3.082560e+00  3.201008e+00  1.822500e+00  1.206251e+00  1.038889e+00
#
#                fuel      odometer  title_status  transmission         drive  \
# count  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05
# mean  -9.187411e-18 -4.511280e-17 -6.155767e-17 -9.135142e-17 -2.979375e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -2.671929e+00 -1.531649e+00 -2.223574e-01 -5.129090e-01 -1.181948e+00
# 25%   -8.463084e-02 -8.760458e-01 -2.223574e-01 -5.129090e-01 -1.181948e+00
# 50%   -8.463084e-02 -6.001883e-02 -2.223574e-01 -5.129090e-01 -3.539655e-01
# 75%   -8.463084e-02  7.124214e-01 -2.223574e-01 -5.129090e-01  1.302000e+00
# max    3.796317e+00  3.024037e+00  5.391516e+00  3.333261e+00  1.302000e+00
#
#                size          type   paint_color         state
# count  3.534380e+05  3.534380e+05  3.534380e+05  3.534380e+05
# mean  -1.148728e-16 -2.384304e-17 -2.609466e-17 -5.789879e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -2.455686e+00 -1.649772e+00 -1.643152e+00 -1.558421e+00
# 25%   -9.318755e-01 -7.656824e-01 -9.799871e-01 -9.630848e-01
# 50%    5.919350e-01  3.394300e-01  3.463421e-01 -3.700658e-02
# 75%    5.919350e-01  7.814750e-01  1.009507e+00  8.890716e-01
# max    5.919350e-01  1.223520e+00  1.009507e+00  1.749001e+00

# %% [markdown]
# # Data Splitting

# %%
dataframe
# Out:
#            price      year  manufacturer  condition  cylinders      fuel  \
# 0      -1.012483 -0.744682      1.822500   1.206251   1.038889  3.796317
# 1      -0.541889 -0.744509      1.822500   1.206251   1.038889  3.796317
# 2       0.183942 -0.745693      1.822500   1.206251   1.038889  3.796317
# 3      -1.371410 -0.747398      1.822500   1.206251   1.038889  3.796317
# 4      -1.100220 -0.748753      1.822500   1.206251   1.038889  3.796317
# ...          ...       ...           ...        ...        ...       ...
# 426875  0.390525 -1.207894      0.924766  -0.435308  -0.511527 -0.084631
# 426876  0.948856 -1.391598      1.740888  -0.435308   1.038889 -0.084631
# 426877  1.299807 -1.391598     -1.115538  -0.435308   1.038889 -2.671929
# 426878  0.821237 -1.024189      0.271869  -0.435308  -0.511527 -0.084631
# 426879  0.948856 -1.207894     -1.278762  -0.435308   1.038889 -0.084631
#
#         odometer  title_status  transmission     drive      size      type  \
# 0      -1.321877      5.391516      3.333261  1.302000  0.591935  1.223520
# 1      -1.321760      5.391516      3.333261  1.302000  0.591935  1.223520
# 2      -1.322439      5.391516      3.333261  1.302000  0.591935  1.223520
# 3      -1.323498      5.391516      3.333261  1.302000  0.591935  1.223520
# 4      -1.324294      5.391516      3.333261  1.302000  0.591935  1.223520
# ...          ...           ...           ...       ...       ...       ...
# 426875 -0.998786     -0.222357      2.051204 -0.353966  0.591935  0.339430
# 426876 -1.332747     -0.222357      2.051204 -0.353966  0.591935  0.339430
# 426877 -1.462631     -0.222357      2.051204  1.302000  0.591935 -0.765682
# 426878 -1.033742     -0.222357      2.051204 -0.353966  0.591935  0.339430
# 426879 -1.156036     -0.222357      2.051204  0.474017  0.591935 -0.986705
#
#         paint_color     state
# 0          1.009507 -1.359975
# 1          1.009507 -1.426124
# 2          1.009507 -0.963085
# 3          1.009507 -0.301600
# 4          1.009507  0.227587
# ...             ...       ...
# 426875     1.009507  1.749001
# 426876     0.125287  1.749001
# 426877     0.567397  1.749001
# 426878     0.346342  1.749001
# 426879     1.009507  1.749001
#
# [353438 rows x 14 columns]

# %%
y = dataframe['price']
x = dataframe.drop('price',axis= 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error,median_absolute_error
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=10)

# %% [markdown]
# # Regression Model and Prediction

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import warnings
warnings.filterwarnings('ignore')

output=[]
output.append(["Regression Algorithm","RMSE","R Squared","Mean Squared Error","Absolute Mean Error","Median e"])
dictout={}
dictout1={}
dictout2={}

# %%
def train_test_model(model,model_name,X_train,y_train,X_test,y_test):
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)
    
    plt.figure(figsize=(10,10))
    plt.xlabel("Actual price")
    plt.ylabel("Predicted price")
    plt.title(model_name)
    plt.plot( y_test, predictions,'b.',alpha=0.05)
    plt.plot(y_test,y_test,'r-')
    plt.legend(['Predicted pric','Actual Price'],loc='upper left')
    plt.show()
    '''
    a=[]
    j=0
    for i in y_test.index:
        if abs(predictions[j]-y_test[i])>30000:
            a.append(i)
        j=j+1
    t=X_test.loc[a]
    #t.describe()
    print( t.describe())
    for i in t.columns:
        print(t[i].value_counts())
        
    '''
    mse=mean_squared_error(y_test, predictions)
    mae=mean_absolute_error(y_test, predictions)
    rs=model.score(X_test,y_test, sample_weight=None)
    rmse=math.sqrt(mse)
    maelog=median_absolute_error(y_test,predictions)
    print(model_name,'\nMean Squared error : ', mse)
    print('Mean Absolute error : ', mae)
    print("R-Squared error",rs)
    print("Root Mean Squared Error: ",rmse)
    print("Median ame",maelog)

    output.append([model_name,rmse,rs,mse,mae,maelog])
    dictout[model_name]=rmse
    dictout1[model_name]=rs
    dictout2[model_name]=maelog

# %% [markdown]
# def train_test_model(model,model_name,X_train,y_train,X_test,y_test):
#     model.fit(X_train,y_train)
#     predictions = model.predict(X_test)
#
#     plt.figure(figsize=(10,10))
#     plt.xlabel("Actual price")
#     plt.ylabel("Predicted price")
#     plt.title(model_name)
#     plt.plot( y_test, predictions,'b.',alpha=0.05)
#     plt.plot(y_test,y_test,'r-')
#     plt.legend(['Predicted pric','Actual Price'],loc='upper left')
#     plt.show()
#
#     #t=X_train[abs(predictions-y_test)]
#     #print(y_test.index)
#     predictions=pd.DataFrame(predictions)
#     predictions.index=y_test.index
#     print(predictions)
#     for i in y_test.index:
#         p=predictions[i]
#         if abs(p-y_test[i])>30000:
#             print(i)
#             #print(X_test.iloc[i])
#     "
#     mse=mean_squared_error(y_test, predictions)
#     mae=mean_absolute_error(y_test, predictions)
#     rs=model.score(X_test,y_test, sample_weight=None)
#     rmse=math.sqrt(mse)
#     print(model_name,'\nMean Squared error : ', mse)
#     print('Mean Absolute error : ', mae)
#     print("R-Squared error",rs)
#     print("Root Mean Squared Error: ",rmse)
#
#     output.append([model_name,rmse,rs,mse,mae])
#     dictout[model_name]=rmse
#     dictout1[model_name]=rs

# %% [markdown]
# ## Multiple Linear regression
# ### Multiple Linear regression model is the quickest and easiest regression model but the precision is lower than other models and used only in certain problems. It uses weights to fit the training data in a straight-line and weights are adjusted by minimizing the mean squared error loss.

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)
train_test_model(model,"Linear Regression",X_train,y_train,X_test,y_test)
# Out:
# Linear Regression
# Mean Squared error :  0.48435229503205735
# Mean Absolute error :  0.5413833613414857
# R-Squared error 0.5177246906450592
# Root Mean Squared Error:  0.6959542334320967
# Median ame 0.44399602520618014

# %% [markdown]
# ## Ridge Regression
# ### Ridge regression is a regularized version of linear regressor but has alpha parameter to control the regulation of the model to reduce the variance of the estimates.

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=1,fit_intercept=True,random_state=1)
train_test_model(model,"Ridge Regression",X_train,y_train,X_test,y_test)
# Out:
# Ridge Regression
# Mean Squared error :  0.4843522946004546
# Mean Absolute error :  0.5413833908495276
# R-Squared error 0.5177246910748112
# Root Mean Squared Error:  0.6959542331220169
# Median ame 0.44399650298335375

# %% [markdown]
# ## LASSO Regression
# ### LASSO stands for Least Absolute Shrinkage and Selection Operator which is a shrinkage regularization technique. It is a simple sparse model which has only fewer parameters than ridge or linear regression. This type of regression is used when the dataset shows high multi collinearity or when you want to automate variable elimination and feature selection.

# %%
from sklearn.linear_model import Lasso

model = Lasso(fit_intercept=True,random_state=1)
train_test_model(model,"Lasso Regression",X_train,y_train,X_test,y_test)
# Out:
# Lasso Regression
# Mean Squared error :  1.004371079056254
# Mean Absolute error :  0.837425670261676
# R-Squared error -6.41636826581582e-05
# Root Mean Squared Error:  1.0021831564421015
# Median ame 0.8146840758862169

# %% [markdown]
# ## Bayesian Regression
# ### Bayesian regression is a type of linear regression which can be implemented with insufficient data or poorly distributed data using probability distributors rather than point estimates.

# %%
from sklearn.linear_model import BayesianRidge
model=BayesianRidge(fit_intercept=True)

train_test_model(model,"Bayesian Regression",X_train,y_train,X_test,y_test)
# Out:
# Bayesian Regression
# Mean Squared error :  0.4843522884100224
# Mean Absolute error :  0.5413838963661822
# R-Squared error 0.5177246972386977
# Root Mean Squared Error:  0.6959542286745749
# Median ame 0.4440123335331039

# %% [markdown]
# ## Decision Tree
# ## Decision Tree a widely used model to handle missing values with high dimensional data. It is more effective and provides optimum accuracy with minimum number of features.

# %% [markdown]
# print('Decision Tree Regressor with different depth')
# from sklearn.tree import DecisionTreeRegressor
# from sklearn import tree
#
# for k in range(15,30):
#     model = DecisionTreeRegressor(max_depth=k,max_features='auto',random_state=1)
#     model.fit(X_train,y_train)
#     predictions = model.predict(X_test)
#     print('Depth',k,'RMSE : ',  math.sqrt(mean_squared_error(y_test, predictions)),'   R SQUARE:',model.score(X_test,y_test, sample_weight=None))

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
model = DecisionTreeRegressor(max_depth=23,max_features='auto',random_state=1)

train_test_model(model,"Decision Tree Regression",X_train,y_train,X_test,y_test)
# Out:
# Decision Tree Regression
# Mean Squared error :  0.14596435223659962
# Mean Absolute error :  0.18581648947575705
# R-Squared error 0.8546615679295162
# Root Mean Squared Error:  0.3820528134127527
# Median ame 0.04944423887508376

# %% [markdown]
# ## Random Forest Regression
# ### Random forest regression is a classifier based on ensemble Machine Learning model which is used in decision tree framework to create a random decision tree. It has a better prediction accuracy compared to normal regression.

# %% [markdown]
# print('Random Forest Regressor with different depth')
# from sklearn.ensemble import RandomForestRegressor
# for k in range(29,39):
#     model = RandomForestRegressor(n_estimators=100,max_depth=k,max_features='log2',random_state=1)
#     model.fit(X_train,y_train)
#     predictions = model.predict(X_test)
#     print('Depth',k,'RMSE : ',  math.sqrt(mean_squared_error(y_test, predictions)),'   R SQUARE:',model.score(X_test,y_test, sample_weight=None))

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100,max_depth=33,max_features='log2',random_state=1)
train_test_model(model,"Random Forest Regression",X_train,y_train,X_test,y_test)
# Out:
# Random Forest Regression
# Mean Squared error :  0.07320010840776582
# Mean Absolute error :  0.14613040609672576
# R-Squared error 0.927113786206311
# Root Mean Squared Error:  0.27055518551261554
# Median ame 0.06043459485927094

# %% [markdown]
# ## Multi-layer Perceptron
# ### Multi-layer Perceptron (MLP) Regression Algorithm is a type of supervised learning which emulate a function from the input dataset. It is an artificial neural network composed of multiple layers of perceptron. It uses hidden layers and neurons to predict the value of the unknown input.

# %%
from sklearn.neural_network import MLPRegressor
model=MLPRegressor(hidden_layer_sizes=(28,28,42,1),activation='relu',learning_rate='adaptive', learning_rate_init=0.1, solver='adam', max_iter=320,random_state=1,verbose=True,early_stopping=True,n_iter_no_change=70)
train_test_model(model,"MLP Regression",X_train,y_train,X_test,y_test)
# Out:
# Iteration 1, loss = 0.17204780
# Validation score: 0.726955
# Iteration 2, loss = 0.13681376
# Validation score: 0.692078
# Iteration 3, loss = 0.13629638
# Validation score: 0.736096
# Iteration 4, loss = 0.13692783
# Validation score: 0.731938
# Iteration 5, loss = 0.14169059
# Validation score: 0.738119
# Iteration 6, loss = 0.14273459
# Validation score: 0.691010
# Iteration 7, loss = 0.14308787
# Validation score: 0.684878
# Iteration 8, loss = 0.15744628
# Validation score: 0.703564
# Iteration 9, loss = 0.14124019
# Validation score: 0.617058
# Iteration 10, loss = 0.14719780
# Validation score: 0.714021
# Iteration 11, loss = 0.14578921
# Validation score: 0.710497
# Iteration 12, loss = 0.14950196
# Validation score: 0.703604
# Iteration 13, loss = 0.14205226
# Validation score: 0.477022
# Iteration 14, loss = 0.15069820
# Validation score: 0.668749
# Iteration 15, loss = 0.15139683
# Validation score: 0.636162
# Iteration 16, loss = 0.19363092
# Validation score: 0.587640
# Iteration 17, loss = 0.16086015
# Validation score: 0.677150
# Iteration 18, loss = 0.15500397
# Validation score: 0.654437
# Iteration 19, loss = 0.14287965
# Validation score: 0.720912
# Iteration 20, loss = 0.13628006
# Validation score: 0.679542
# Iteration 21, loss = 0.13781113
# Validation score: 0.743899
# Iteration 22, loss = 0.13626778
# Validation score: 0.726787
# Iteration 23, loss = 0.13383150
# Validation score: 0.629082
# Iteration 24, loss = 0.13198623
# Validation score: 0.738900
# Iteration 25, loss = 0.13360135
# Validation score: 0.725442
# Iteration 26, loss = 0.13290361
# Validation score: 0.744557
# Iteration 27, loss = 0.22074423
# Validation score: -0.005278
# Iteration 28, loss = 0.50235274
# Validation score: -0.001997
# Iteration 29, loss = 0.50190850
# Validation score: -0.000987
# Iteration 30, loss = 0.50188825
# Validation score: -0.001231
# Iteration 31, loss = 0.50168574
# Validation score: -0.000717
# Iteration 32, loss = 0.50089721
# Validation score: -0.003032
# Iteration 33, loss = 0.50095542
# Validation score: -0.000479
# Iteration 34, loss = 0.50092319
# Validation score: -0.000621
# Iteration 35, loss = 0.50114033
# Validation score: -0.003830
# Iteration 36, loss = 0.50117624
# Validation score: -0.000278
# Iteration 37, loss = 0.50132982
# Validation score: -0.002335
# Iteration 38, loss = 0.50093731
# Validation score: -0.001874
# Iteration 39, loss = 0.50091256
# Validation score: -0.002054
# Iteration 40, loss = 0.50092154
# Validation score: -0.000525
# Iteration 41, loss = 0.50115550
# Validation score: -0.000010
# Iteration 42, loss = 0.50107033
# Validation score: -0.001744
# Iteration 43, loss = 0.50090880
# Validation score: -0.003903
# Iteration 44, loss = 0.50074849
# Validation score: -0.002885
# Iteration 45, loss = 0.50111972
# Validation score: -0.000004
# Iteration 46, loss = 0.50121275
# Validation score: -0.004658
# Iteration 47, loss = 0.50078523
# Validation score: -0.000104
# Iteration 48, loss = 0.50081532
# Validation score: -0.005521
# Iteration 49, loss = 0.50105037
# Validation score: -0.001476
# Iteration 50, loss = 0.50094511
# Validation score: -0.000413
# Iteration 51, loss = 0.50085920
# Validation score: -0.000258
# Iteration 52, loss = 0.50133741
# Validation score: -0.000997
# Iteration 53, loss = 0.50093128
# Validation score: -0.002364
# Iteration 54, loss = 0.50099342
# Validation score: -0.001130
# Iteration 55, loss = 0.50088155
# Validation score: -0.000613
# Iteration 56, loss = 0.50100015
# Validation score: -0.006681
# Iteration 57, loss = 0.50098856
# Validation score: -0.000318
# Iteration 58, loss = 0.50109160
# Validation score: -0.000020
# Iteration 59, loss = 0.50107302
# Validation score: -0.000098
# Iteration 60, loss = 0.50107322
# Validation score: -0.004222
# Iteration 61, loss = 0.50170034
# Validation score: -0.000026
# Iteration 62, loss = 0.50077548
# Validation score: -0.004612
# Iteration 63, loss = 0.50109824
# Validation score: -0.001608
# Iteration 64, loss = 0.50101684
# Validation score: -0.001742
# Iteration 65, loss = 0.50088229
# Validation score: -0.000001
# Iteration 66, loss = 0.50088626
# Validation score: -0.010634
# Iteration 67, loss = 0.50115970
# Validation score: -0.003650
# Iteration 68, loss = 0.50097185
# Validation score: -0.010321
# Iteration 69, loss = 0.50126788
# Validation score: -0.005122
# Iteration 70, loss = 0.50067752
# Validation score: -0.009430
# Iteration 71, loss = 0.50104007
# Validation score: -0.007197
# Iteration 72, loss = 0.50110072
# Validation score: -0.010824
# Iteration 73, loss = 0.50134597
# Validation score: -0.006421
# Iteration 74, loss = 0.50075381
# Validation score: -0.000734
# Iteration 75, loss = 0.50104099
# Validation score: -0.007989
# Iteration 76, loss = 0.50102474
# Validation score: -0.001617
# Iteration 77, loss = 0.50107263
# Validation score: -0.003905
# Iteration 78, loss = 0.50109845
# Validation score: -0.000308
# Iteration 79, loss = 0.50115316
# Validation score: -0.000816
# Iteration 80, loss = 0.50087296
# Validation score: -0.007196
# Iteration 81, loss = 0.50100336
# Validation score: -0.000011
# Iteration 82, loss = 0.50095217
# Validation score: -0.001187
# Iteration 83, loss = 0.50079652
# Validation score: -0.002117
# Iteration 84, loss = 0.50093873
# Validation score: -0.001687
# Iteration 85, loss = 0.50120914
# Validation score: -0.000002
# Iteration 86, loss = 0.50110734
# Validation score: -0.001992
# Iteration 87, loss = 0.50102404
# Validation score: -0.001880
# Iteration 88, loss = 0.50100461
# Validation score: -0.020150
# Iteration 89, loss = 0.50103394
# Validation score: -0.000094
# Iteration 90, loss = 0.50090528
# Validation score: -0.000921
# Iteration 91, loss = 0.50122125
# Validation score: -0.000001
# Iteration 92, loss = 0.50081670
# Validation score: -0.000804
# Iteration 93, loss = 0.50140030
# Validation score: -0.000155
# Iteration 94, loss = 0.50080681
# Validation score: -0.005185
# Iteration 95, loss = 0.50077449
# Validation score: -0.000794
# Iteration 96, loss = 0.50090745
# Validation score: -0.004956
# Iteration 97, loss = 0.50093337
# Validation score: -0.000494
# Validation score did not improve more than tol=0.000100 for 70 consecutive epochs. Stopping.
# MLP Regression
# Mean Squared error :  0.24953341421056988
# Mean Absolute error :  0.3554085760258357
# R-Squared error 0.7515366278488841
# Root Mean Squared Error:  0.4995331963048801
# Median ame 0.2481654628338772

# %% [markdown]
# ## Light gradient-boosting
# ### Light gradient-boosting ensemble machine learning models which has XG Boost advantages.

# %% [markdown]
# from lightgbm import LGBMRegressor
# print('Light gradient-boosting Regressor with different depth')
# for k in range(12,19):
#     model=LGBMRegressor(max_depth=k,random_state=1)
#     model.fit(X_train,y_train)
#     predictions = model.predict(X_test)
#     print('Depth',k,'RMSE : ',  math.sqrt(mean_squared_error(y_test, predictions)),'   R SQUARE:',model.score(X_test,y_test, sample_weight=None))

# %%
from lightgbm import LGBMRegressor
model=LGBMRegressor(max_depth=16,random_state=1)

train_test_model(model,"LGBM Regression",X_train,y_train,X_test,y_test)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# LGBM Regression
# Mean Squared error :  0.16602140308653868
# Mean Absolute error :  0.2833833671464149
# R-Squared error 0.834690525152147
# Root Mean Squared Error:  0.40745724080759527
# Median ame 0.1938336667480249

# %% [markdown]
# ## XG Boost
# ### XG Boost ensemble learning models uses loss function and a regularization term.

# %% [markdown]
# print('XGB Regressor with different depth')
# import warnings
# warnings.filterwarnings('ignore')
# import xgboost as xg
# for k in range(12, 19):
#     model =xg.XGBRegressor(max_depth=k,random_state=1)
#     model.fit(X_train,y_train)
#     predictions = model.predict(X_test)
#     print('Depth',k,'RMSE : ',  math.sqrt(mean_squared_error(y_test, predictions)),'   R SQUARE:',model.score(X_test,y_test, sample_weight=None))

# %%
import xgboost as xg
model=xg.XGBRegressor(max_depth=14,random_state=1)

train_test_model(model,"XGB Regression",X_train,y_train,X_test,y_test)
# Out:
# XGB Regression
# Mean Squared error :  0.0706267347272689
# Mean Absolute error :  0.14575149098923315
# R-Squared error 0.9296761248192938
# Root Mean Squared Error:  0.26575690908661037
# Median ame 0.06447497640156885

# %% [markdown]
# ## Gradient Boosted Regression
# ### Gradient boosted regression is ensemble model same as the random forest regression but in gradient boosted it creates multiple trees to improve the deficiencies in the previous tree so absolute mean error will be the least. It can be modified with the learning rate and loss function. It is important to note that the learning rate should not be high so the tree will not be overfitted.

# %% [markdown]
# ##### print('Gradient Boosting Regressor with different depth')
# from sklearn.ensemble import GradientBoostingRegressor
# for k in range(10, 17):
#     model =GradientBoostingRegressor(max_depth=k,random_state=1)
#     model.fit(X_train,y_train)
#     predictions = model.predict(X_test)
#     print('Depth',k,'RMSE : ',  math.sqrt(mean_squared_error(y_test, predictions)),'   R SQUARE:',model.score(X_test,y_test, sample_weight=None))

# %%
from sklearn.ensemble import GradientBoostingRegressor
model=GradientBoostingRegressor(max_depth=16,random_state=1)

train_test_model(model,"Gradient Boost Regression",X_train,y_train,X_test,y_test)
# Out:
# Gradient Boost Regression
# Mean Squared error :  0.07247081150913778
# Mean Absolute error :  0.1423660614426204
# R-Squared error 0.927839955754809
# Root Mean Squared Error:  0.26920403323341535
# Median ame 0.05869891450640291

# %%
pd.DataFrame(output)
# Out:
#                             0         1          2                   3  \
# 0        Regression Algorithm      RMSE  R Squared  Mean Squared Error
# 1           Linear Regression  0.695954   0.517725            0.484352
# 2            Ridge Regression  0.695954   0.517725            0.484352
# 3            Lasso Regression  1.002183  -0.000064            1.004371
# 4         Bayesian Regression  0.695954   0.517725            0.484352
# 5    Decision Tree Regression  0.382053   0.854662            0.145964
# 6    Random Forest Regression  0.270555   0.927114              0.0732
# 7              MLP Regression  0.499533   0.751537            0.249533
# 8             LGBM Regression  0.407457   0.834691            0.166021
# 9              XGB Regression  0.265757   0.929676            0.070627
# 10  Gradient Boost Regression  0.269204    0.92784            0.072471
#
#                       4         5
# 0   Absolute Mean Error  Median e
# 1              0.541383  0.443996
# 2              0.541383  0.443997
# 3              0.837426  0.814684
# 4              0.541384  0.444012
# 5              0.185816  0.049444
# 6               0.14613  0.060435
# 7              0.355409  0.248165
# 8              0.283383  0.193834
# 9              0.145751  0.064475
# 10             0.142366  0.058699

# %%
courses = list(dictout.keys())
values = list(dictout.values())

plt.figure(figsize = (10, 10))
plt.xlabel("RMSE")
plt.ylabel("Regression Algorithm")
plt.barh(courses, values,height=0.3)
plt.title("RMSE of Regression Algorithm")
plt.show()

# %%
courses = list(dictout1.keys())
values = list(dictout1.values())

plt.figure(figsize =(10, 10))
plt.xlabel("R SQUARE")
plt.ylabel("Regression Algorithm")
plt.barh(courses, values,height=0.3)
plt.title("R Square of Regression Algorithm")
plt.show()

# %%
courses = list(dictout2.keys())
values = list(dictout2.values())

plt.figure(figsize =(10, 10))
plt.xlabel("MSEL")
plt.ylabel("Regression Algorithm")
plt.barh(courses, values,height=0.3)
plt.title("Mean Squared Error Log of Regression Algorithm")
plt.show()
